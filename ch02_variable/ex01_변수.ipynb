# %%
# 변수란?
friend = 1
Friend = 10
print(friend)
print(Friend)
# Out:
# 1
# 10

# %%
# 변수를 만드는 여러가지 방법
a, b = ('python', 'life')
(a, b) = 'python', 'life'
print(a)
print(b)
a = b = 'python'
print(a)
print(b)
# Out:
# python
# life
# python
# python

# %%
# 메모리에 생성된 변수 없애기
a = 3
b = 3
print(a)
print(b)
del(a)  # del은 내장함수로 인수의 변수를 메모리에서 삭제한다.
del(b)
print(a)
print(b)
# Out:
# 3
# 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-006f84b97403> in <module>
#       6 del(a)  # del은 내장함수로 인수의 변수를 메모리에서 삭제한다.
#       7 del(b)
# ----> 8 print(a)
#       9 print(b)
#
# NameError: name 'a' is not defined

# %%
# 리스트를 변수에 넣고 복사하고자 할 때
# 리스트 자료형
a = [1, 2, 3]
b = a   # 얕은 복사 (주소가 복사하기)   vs 깊은 복사 (객체를 새롭게 생성하기)
a[1] = 4
print(a)
# Out:
# [1, 4, 3]

# %%
print(b)
# Out:
# [1, 4, 3]

# %%
# copy 모듈 이용
from copy import copy
b = copy(a)  # 깊은 복사(deep copy)
print(a)
print(b)
# Out:
# [1, 4, 3]
# [1, 4, 3]

# %%
a[1] = 5
print(a)
print(b)
# Out:
# [1, 5, 3]
# [1, 4, 3]
